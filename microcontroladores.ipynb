# %% [markdown]
# ### Estatísticas de produtos - Mercado Livre
#
# #### Categoria: Microcontroladores
#
# Obs.: "n_sells" é a quantidade total de vendas do item

# %%
import pandas as pd

pd.options.display.max_rows = 1000

df = pd.read_json('microcontroladores.jsonl', lines = True)
df = df[df['n_sells'] > 0]
df = df.sort_values(by=['n_sells'], ascending=False)
df = df[['name', 'n_sells', 'state']]
df.head(1000)
# Out:
#                                                    name  n_sells  \
# 6      Raspberry Pi3 Pi 3 Model B Quadcore 1.2ghz Na...     5937
# 12     Kit Case Preto + Fonte + Raspberry Pi3 + Diss...     4333
# 7      Pastilha Placa Termoelétrica Peltier Tec1-127...     3412
# 13     Vídeo Game Retro Raspberry Pi3 2 Controle Com...     3289
# 41     Arduino Uno Rev3 R3 Atmega328 Dip Com Cabo Us...     3249
# 485    Microcontrolador Arduino Uno R3 Rev3 Atmega32...     2190
# 1394   Fonte Micro Usb 5v 3a Para O Raspberry Pi 1 -...     2140
# 67     Kit Arduino Uno R3 Básico + Servo + Protoboar...     2080
# 34     Raspberry Pi 3 Model B Pi3 Quadcore + Fonte 3...     1814
# 14               Arduino Pro Mini 5 Atmega328 16mhz 5v      1536
# 44     Kit Arduino Uno Smd R3 Iniciante + Protoboard...     1383
# 1469   Raspberry 3 + Case + Fonte 5v + Dissipador + ...     1244
# 1898   Raspberry Pi3 (pi 3 Pi 3 )pi3 Quadcore+diss+c...     1218
# ...
